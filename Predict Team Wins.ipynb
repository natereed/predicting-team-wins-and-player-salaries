# %%
import numpy as np
import pandas as pd
import os

teams_df = pd.read_csv(os.path.join("data", "lahman", "baseballdatabank-master", "core", "Teams.csv"))
teams_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L     ...       \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10     ...
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9     ...
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19     ...
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12     ...
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17     ...
#
#    DP    FP                     name                          park  \
# 0 NaN  0.83     Boston Red Stockings           South End Grounds I
# 1 NaN  0.82  Chicago White Stockings       Union Base-Ball Grounds
# 2 NaN  0.81   Cleveland Forest Citys  National Association Grounds
# 3 NaN  0.80     Fort Wayne Kekiongas                Hamilton Field
# 4 NaN  0.83         New York Mutuals      Union Grounds (Brooklyn)
#
#    attendance  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0         NaN  103   98       BOS             BS1          BS1
# 1         NaN  104  102       CHI             CH1          CH1
# 2         NaN   96  100       CLE             CL1          CL1
# 3         NaN  101  107       KEK             FW1          FW1
# 4         NaN   90   88       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Subset

# %%
subset_columns = ['G', 'W', 'L']
subset_columns.extend(teams_df.columns[14:-3].values)
subset_columns.remove('name')
subset_columns.remove('park')
subset_columns.remove('attendance')
teams_df = pd.DataFrame(teams_df, columns=subset_columns)
teams_df.head()
# Out:
#     G   W   L    R    AB    H  2B  3B  HR  BB ...   IPouts   HA  HRA  BBA  \
# 0  31  20  10  401  1372  426  70  37   3  60 ...      828  367    2   42
# 1  28  19   9  302  1196  323  52  21  10  60 ...      753  308    6   28
# 2  29  10  19  249  1186  328  35  40   7  26 ...      762  346   13   53
# 3  19   7  12  137   746  178  19   8   2  33 ...      507  261    5   21
# 4  33  16  17  302  1404  403  43  21   1  33 ...      879  373    7   42
#
#    SOA    E  DP    FP  BPF  PPF
# 0   23  225 NaN  0.83  103   98
# 1   22  218 NaN  0.82  104  102
# 2   34  223 NaN  0.81   96  100
# 3   17  163 NaN  0.80  101  107
# 4   22  227 NaN  0.83   90   88
#
# [5 rows x 31 columns]

# %%
teams_df['Winning Percentage'] = teams_df['W'] / (teams_df['W'] + teams_df['L'])
teams_df.head()
# Out:
#     G   W   L    R    AB    H  2B  3B  HR  BB         ...           HA  HRA  \
# 0  31  20  10  401  1372  426  70  37   3  60         ...          367    2
# 1  28  19   9  302  1196  323  52  21  10  60         ...          308    6
# 2  29  10  19  249  1186  328  35  40   7  26         ...          346   13
# 3  19   7  12  137   746  178  19   8   2  33         ...          261    5
# 4  33  16  17  302  1404  403  43  21   1  33         ...          373    7
#
#    BBA  SOA    E  DP    FP  BPF  PPF  Winning Percentage
# 0   42   23  225 NaN  0.83  103   98            0.666667
# 1   28   22  218 NaN  0.82  104  102            0.678571
# 2   53   34  223 NaN  0.81   96  100            0.344828
# 3   21   17  163 NaN  0.80  101  107            0.368421
# 4   42   22  227 NaN  0.83   90   88            0.484848
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Normalization

# %%
for column in teams_df.columns:
     teams_df[column] = (teams_df[column] - teams_df[column].min()) / (teams_df[column].max() - teams_df[column].min())
teams_df = teams_df.round(3)
teams_df = teams_df.fillna(0.0)
teams_df.head()
teams_df.head()
# Out:
#        G      W      L      R     AB      H     2B     3B     HR     BB  \
# 0  0.157  0.172  0.046  0.315  0.208  0.225  0.180  0.247  0.011  0.072
# 1  0.138  0.164  0.038  0.232  0.177  0.166  0.131  0.140  0.038  0.072
# 2  0.145  0.086  0.115  0.188  0.175  0.169  0.086  0.267  0.027  0.031
# 3  0.082  0.060  0.062  0.094  0.096  0.083  0.043  0.053  0.008  0.040
# 4  0.170  0.138  0.100  0.232  0.214  0.211  0.107  0.140  0.004  0.040
#
#           ...             HA    HRA    BBA    SOA      E   DP     FP    BPF  \
# 0         ...          0.164  0.008  0.051  0.016  0.301  0.0  0.303  0.623
# 1         ...          0.133  0.025  0.034  0.015  0.289  0.0  0.260  0.638
# 2         ...          0.153  0.054  0.064  0.023  0.297  0.0  0.216  0.522
# 3         ...          0.109  0.021  0.025  0.012  0.196  0.0  0.173  0.594
# 4         ...          0.167  0.029  0.051  0.015  0.304  0.0  0.303  0.435
#
#      PPF  Winning Percentage
# 0  0.469               0.742
# 1  0.519               0.755
# 2  0.494               0.384
# 3  0.580               0.410
# 4  0.346               0.539
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Regression Model

# %%
y = np.asarray(teams_df['Winning Percentage'])
teams_df.drop(['Winning Percentage', 'G', 'W', 'L'],inplace=True,axis=1)
X = np.asarray(teams_df)

# %%
y

# %%
from sklearn import linear_model
from sklearn import cross_validation

regr = linear_model.LinearRegression()
x_train, x_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.3, random_state=55)
regr.fit(x_train, y_train)
score = regr.score(x_test, y_test)
print(score)
# Out:
# 0.915994428193

# %%
regr.coef_
# Out:
# array([ 0.88166259, -0.39066642,  0.00736825, -0.01692215, -0.02933152,
#        -0.05329997, -0.04784067,  0.00515573, -0.03742941, -0.00466127,
#         0.006104  , -0.01342295, -0.67345721,  0.39531509, -0.34139359,
#         0.07038364,  0.0437575 ,  0.11423094,  0.04358548, -0.04932805,
#        -0.00136819, -0.00936989, -0.02105822,  0.0622386 ,  0.00195577,
#         0.21093697,  0.52711669, -0.60848766])

# %%
teams_df.head()
# Out:
#        R     AB      H     2B     3B     HR     BB     SO     SB   CS  ...    \
# 0  0.315  0.208  0.225  0.180  0.247  0.011  0.072  0.012  0.126  0.0  ...
# 1  0.232  0.177  0.166  0.131  0.140  0.038  0.072  0.014  0.119  0.0  ...
# 2  0.188  0.175  0.169  0.086  0.267  0.027  0.031  0.016  0.031  0.0  ...
# 3  0.094  0.096  0.083  0.043  0.053  0.008  0.040  0.006  0.028  0.0  ...
# 4  0.232  0.214  0.211  0.107  0.140  0.004  0.040  0.010  0.079  0.0  ...
#
#    IPouts     HA    HRA    BBA    SOA      E   DP     FP    BPF    PPF
# 0   0.153  0.164  0.008  0.051  0.016  0.301  0.0  0.303  0.623  0.469
# 1   0.136  0.133  0.025  0.034  0.015  0.289  0.0  0.260  0.638  0.519
# 2   0.138  0.153  0.054  0.064  0.023  0.297  0.0  0.216  0.522  0.494
# 3   0.079  0.109  0.021  0.025  0.012  0.196  0.0  0.173  0.594  0.580
# 4   0.165  0.167  0.029  0.051  0.015  0.304  0.0  0.303  0.435  0.346
#
# [5 rows x 28 columns]

# %%
teams_df.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'CS', 'HBP', 'SF',
#        'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'IPouts', 'HA', 'HRA', 'BBA',
#        'SOA', 'E', 'DP', 'FP', 'BPF', 'PPF'],
#       dtype='object')
