# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
import os
df = pd.read_csv(os.path.join("data", "db", "Observations.csv"))

# %%
df['Annual Salary'] = df['Annual Salary'].str.replace("$", "")
df['Annual Salary'] = df['Annual Salary'].str.replace(",", "")
df['Annual Salary'] = pd.to_numeric(df['Annual Salary'])
df['Log Annual Salary'] = np.log(df['Annual Salary'])
df.head()
# Out:
#   Player Id  Salary Year  Annual Salary Contract Years  \
# 0     bchen         2014        3000000       1 (2014)
# 1    jloney         2013        2000000       1 (2013)
# 2   esogard         2014         510000       1 (2014)
# 3  ujimenez         2013        5750000       1 (2013)
# 4  jsanchez         2013        1375000       1 (2013)
#
#    Advanced Pitching_BABIP.Year-1  Advanced Pitching_BABIP.Year-2  \
# 0                           0.257                           0.305
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                           0.310                           0.947
# 4                           1.051                           0.276
#
#    Advanced Pitching_BABIP.Year-3  Advanced Pitching_BB/9.Year-1  \
# 0                           0.280                           2.68
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                           0.274                           4.84
# 4                           0.255                          21.96
#
#    Advanced Pitching_BB/9.Year-2  Advanced Pitching_BB/9.Year-3  \
# 0                           2.21                           2.90
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                          11.18                           3.74
# 4                           5.86                           4.47
#
#          ...          Pitching_SVO.Year-1  Pitching_SVO.Year-2  \
# 0        ...                          2.0                  0.0
# 1        ...                          NaN                  NaN
# 2        ...                          NaN                  NaN
# 3        ...                          0.0                  0.0
# 4        ...                          0.0                  0.0
#
#    Pitching_SVO.Year-3  Pitching_W.Year-1  Pitching_W.Year-2  \
# 0                  0.0                9.0               11.0
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  0.0                9.0               20.0
# 4                  0.0                2.0                4.0
#
#    Pitching_W.Year-3  Pitching_WHIP.Year-1  Pitching_WHIP.Year-2  \
# 0               12.0                  1.18                  1.37
# 1                NaN                   NaN                   NaN
# 2                NaN                   NaN                   NaN
# 3               19.0                  1.61                  4.22
# 4               13.0                  6.42                  1.44
#
#    Pitching_WHIP.Year-3  Log Annual Salary
# 0                  1.30          14.914123
# 1                   NaN          14.508658
# 2                   NaN          13.142166
# 3                  1.15          15.564710
# 4                  1.23          14.133964
#
# [5 rows x 333 columns]

# %%
contract_years_df = df['Contract Years'].str.extract('(?P<num_years>[0-9]+)\s+\((?P<start_year>[0-9]+\s*)-\s*(?P<end_year>[0-9]+)\)')
# Out:
# C:\Users\Owner\Anaconda3\envs\data_analysis\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':
#      num_years start_year end_year
# 0          NaN        NaN      NaN
# 1          NaN        NaN      NaN
# 2          NaN        NaN      NaN
# 3          NaN        NaN      NaN
# 4          NaN        NaN      NaN
# 5            3       2013       15
# 6          NaN        NaN      NaN
# 7          NaN        NaN      NaN
# 8          NaN        NaN      NaN
# 9          NaN        NaN      NaN
# 10           5       2012       16
# 11         NaN        NaN      NaN
# 12         NaN        NaN      NaN
# 13           5       2013       17
# 14         NaN        NaN      NaN
# 15         NaN        NaN      NaN
# 16         NaN        NaN      NaN
# 17         NaN        NaN      NaN
# 18         NaN        NaN      NaN
# 19         NaN        NaN      NaN
# 20         NaN        NaN      NaN
# 21         NaN        NaN      NaN
# 22           2       2012       13
# 23         NaN        NaN      NaN
# 24           3       2012       14
# 25         NaN        NaN      NaN
# 26         NaN        NaN      NaN
# 27         NaN        NaN      NaN
# 28         NaN        NaN      NaN
# 29         NaN        NaN      NaN
# ...        ...        ...      ...
# 1057         3       2012       14
# 1058       NaN        NaN      NaN
# 1059       NaN        NaN      NaN
# 1060       NaN        NaN      NaN
# 1061       NaN        NaN      NaN
# 1062       NaN        NaN      NaN
# 1063         2       2012       13
# 1064       NaN        NaN      NaN
# 1065       NaN        NaN      NaN
# 1066       NaN        NaN      NaN
# 1067       NaN        NaN      NaN
# 1068       NaN        NaN      NaN
# 1069         4       2014       17
# 1070         2       2013       14
# 1071         5       2013       17
# 1072       NaN        NaN      NaN
# 1073       NaN        NaN      NaN
# 1074         6       2014       19
# 1075         3       2013       15
# 1076       NaN        NaN      NaN
# 1077       NaN        NaN      NaN
# 1078       NaN        NaN      NaN
# 1079         2       2014       15
# 1080       NaN        NaN      NaN
# 1081       NaN        NaN      NaN
# 1082       NaN        NaN      NaN
# 1083       NaN        NaN      NaN
# 1084       NaN        NaN      NaN
# 1085         6       2014       19
# 1086         2       2014       15
#
# [1087 rows x 3 columns]

# %% [markdown]
# ## Top 10 Highest Paid Players

# %%
# Biggest Salaries
df = df.sort(columns=['Annual Salary'], ascending=False)
top_ten = df[:10]
top_ten[['Player Id', 'Annual Salary', 'Batting_Career_Num_Seasons', 'Pitching_Career_Num_Seasons', 'Fielding_POS.Year-1']]
# Out:
# C:\Users\Owner\Anaconda3\envs\data_analysis\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#       Player Id  Annual Salary  Batting_Career_Num_Seasons  \
# 722    ckershaw       30714286                           5
# 142  arodriguez       27500000                          20
# 616  jverlander       25714285                           8
# 999   jhamilton       25000000                           6
# 731     rhoward       25000000                           9
# 629  fhernandez       25000000                           7
# 361    zgreinke       24500000                           8
# 921   csabathia       24400000                          13
# 688     chamels       24000000                           7
# 967        clee       24000000                           0
#
#      Pitching_Career_Num_Seasons Fielding_POS.Year-1
# 722                            5                   P
# 142                            0                  3B
# 616                            9                  SS
# 999                            0                  OF
# 731                            0                  3B
# 629                            8                   P
# 361                            9                   P
# 921                           13                  OF
# 688                            7                  SS
# 967                            1                   P

# %%
df[df['Player Id'] == 'arodriguez']['Batting_Career_Num_Seasons']
# Out:
# 142    20
# Name: Batting_Career_Num_Seasons, dtype: int64

# %%
# Subset columns
df = pd.DataFrame(df, columns=['Annual Salary', 'Log Annual Salary', 'Contract Years', 'Batting_Career_AVG', 'Batting_Career_RBI', 
                               'Pitching_Career_ERA', 'Fielding_Career_FPCT', 
                               'Fielding_POS.Year-1', 'Batting_Career_G', 'Pitching_Career_G', 'Fielding_Career_G',
                               'Batting_Career_Num_Seasons', 'Pitching_Career_Num_Seasons', 'Fielding_Career_Num_Seasons',
                               'Pitching_Career_ER', 'Fielding_Career_A', 'Fielding_Career_PO', 'Fielding_Career_E',
                               'Batting_Career_PSN', 'Batting_Career_SB', 'Batting_Career_HR'])
df.head()
# Out:
# C:\Users\Owner\Anaconda3\envs\data_analysis\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#      Annual Salary  Log Annual Salary  Batting_Career_AVG  Batting_Career_RBI  \
# 722       30714286          17.240238            0.145594                 9.0
# 142       27500000          17.129697            0.299348              1969.0
# 616       25714285          17.062557            0.000000                 0.0
# 999       25000000          17.034386            0.303717               553.0
# 731       25000000          17.034386            0.271337               920.0
#
#      Pitching_Career_ERA  Fielding_Career_FPCT Fielding_POS.Year-1  \
# 722             2.797581              0.988950                   P
# 142                  NaN              0.973057                  3B
# 616             3.410708              0.935976                  SS
# 999                  NaN              0.982524                  OF
# 731                  NaN              0.990581                  3B
#
#      Batting_Career_G  Pitching_Career_G  Fielding_Career_G  \
# 722             146.0              151.0              151.0
# 142            2568.0                0.0             2461.0
# 616              14.0              266.0              266.0
# 999             737.0                0.0             1421.0
# 731            1098.0                0.0             1061.0
#
#      Batting_Career_Num_Seasons  Pitching_Career_Num_Seasons  \
# 722                           5                            5
# 142                          20                            0
# 616                           8                            9
# 999                           6                            0
# 731                           9                            0
#
#      Fielding_Career_Num_Seasons  Pitching_Career_ER  Fielding_Career_A  \
# 722                            5               293.0              147.0
# 142                           20                 0.0             5683.0
# 616                            9               671.0              195.0
# 999                            6                 0.0               74.0
# 731                            9                 0.0              595.0
#
#      Fielding_Career_PO  Fielding_Career_E  Batting_Career_PSN  \
# 722                32.0                2.0                 NaN
# 142              2768.0              234.0          431.532787
# 616               112.0               21.0                 NaN
# 999              2962.0               54.0           67.872549
# 731              9081.0               92.0           23.076923
#
#      Batting_Career_SB  Batting_Career_HR
# 722                0.0                0.0
# 142              322.0              654.0
# 616                0.0                0.0
# 999               43.0              161.0
# 731               12.0              300.0

# %%
sns.distplot(df['Log Annual Salary'])

# %%
sns.stripplot(x="Fielding_POS.Year-1", y="Annual Salary", data=df)

# %%
sns.regplot(x='Batting_Career_AVG', y='Annual Salary', scatter=True, data=df)

# %%
sns.regplot(x='Batting_Career_G', y='Annual Salary', scatter=True, data=df)

# %%
pitching_df = pd.DataFrame(df[df['Pitching_Career_G'] > 0])
sns.regplot(x='Pitching_Career_ERA', y='Annual Salary', scatter=True, data=df)

# %%
pitching_df = pd.DataFrame(df[df['Pitching_Career_G'] > 0])
sns.regplot(x='Pitching_Career_G', y='Annual Salary', scatter=True, data=df)

# %%
fielding_df = pd.DataFrame(df[df['Fielding_Career_G'] > 0])
sns.regplot(x='Fielding_Career_G', y='Annual Salary', scatter=True, data=df)

# %%
sns.regplot(x='Fielding_Career_FPCT', y='Annual Salary', scatter=True, data=df)

# %%
sns.regplot(x='Batting_Career_RBI', y='Annual Salary', scatter=True, data=df)
#batting_df['Batting_Career_RBI']

# %%
sns.regplot(x='Pitching_Career_Num_Seasons', y='Annual Salary', scatter=True, data=df)

# %%
sns.regplot(x='Batting_Career_Num_Seasons', y='Annual Salary', scatter=True, data=df)

# %%
sns.regplot(x='Fielding_Career_Num_Seasons', y='Annual Salary', scatter=True, data=df)
